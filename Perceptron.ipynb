# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("synthetic_student_placement.csv")

# %%
df.head()
# Out:
#     IQ  CGPA  Placed
# 0  117  5.58       0
# 1  107  6.58       1
# 2  119  6.66       1
# 3  132  6.20       0
# 4  106  6.84       1

# %%
sns.scatterplot(x=df['IQ'],y=df['CGPA'],hue=df['Placed'])
# Out:
# <Axes: xlabel='IQ', ylabel='CGPA'>

# %%
x = df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()

# %%
p.fit(x,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[ 14.  , -32.76]])

# %%
p.intercept_
# Out:
# array([-22.])

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\sun rise\anaconda3\lib\site-packages (24.2)
# Collecting pip
#   Using cached pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-25.2-py3-none-any.whl (1.8 MB)
# ERROR: To modify pip, please run the following command:
# C:\Users\SUN RISE\anaconda3\python.exe -m pip install --upgrade pip

# %%
pip show mlxtend
# Out:
# Name: mlxtendNote: you may need to restart the kernel to use updated packages.
#
# Version: 0.23.4
# Summary: Machine Learning Library Extensions
# Home-page: https://github.com/rasbt/mlxtend
# Author:
# Author-email: Sebastian Raschka <mail@sebastianraschka.com>
# License: BSD 3-Clause
# Location: C:\Users\SUN RISE\anaconda3\Lib\site-packages
# Requires: joblib, matplotlib, numpy, pandas, scikit-learn, scipy
# Required-by:

# %%
from mlxtend.plotting import plot_decision_regions
